# %% [markdown]
# # ex2_scientificl
#
# ## Nội dung bài
# Hiện thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1\right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1\right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1\right]$
#
# ## Bài làm
#
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
# generate randomly the center (x,y ) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2  # 0 to 15 point radii
# Out:
# CPU times: total: 0 ns
# Wall time: 6.91 μs

# %%
# Mã kiểm tra dữ liệu
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
# + x: len=50, [0.03, 0.94]: 10 samples [[0.13648022 0.4934075  0.16545091 0.12758779 0.85982746 0.50615769
#  0.90069211 0.43222848 0.60628914 0.51524773]]
# + y: len=50, [0.03, 0.89]: 10 samples [[0.31569221 0.28685276 0.87849156 0.80075528 0.79831666 0.61499423
#  0.16534753 0.27170257 0.13500412 0.06533159]]
# + colors: len=50, [0.01, 0.97]: 10 samples [[0.95293156 0.68397769 0.38249911 0.27068288 0.66849982 0.24595974
#  0.53014088 0.3789593  0.30212599 0.07885627]]
# + area: len=50, [3.55, 703.08]: 10 samples [[430.90819684 651.4173942   23.69983592 288.33628253 201.30724184
#   65.62935149  45.64469581 221.23536349 313.12021722  91.14464414]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # Kết thúc
